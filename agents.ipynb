# %% [markdown]
# # Building Your Own AI Research Agent
#
#
# ### About Me
# - will brown from ai twitter (@willccbb)
# - research lead @ prime intellect
# - spent 2yrs @ morgan stanley doing LLM applications
# - did phd @ columbia on multi-agent learning theory
# - i work on agentic RL stuff (see [willccbb/verifiers](https://github.com/willccbb/verifiers) on github)
#
#
# ### About the Full Course (Production-Ready Agent Engineering: From MCP to RL)
#
# https://maven.com/will-brown-kyle-corbitt/agents-mcp-rl
#
# - runs june 16 - july 4
# - co-teaching with kyle corbitt (@corbtt), ceo of openpipe
# - agent stuff AND rl stuff
#     - two sides of the same coin
#     - course starts with practical
#     - builds towards RL finetuning for OSS models
#     - most patterns have analogues which can be applied to closed/API models
#
# ### Today's Lightning Lesson
# - Basic definitions
# - Function-calling and writing your own tools
# - MCP crash course
# - Connecting MCP servers to clients
# - Scaffolding a "deep research"

# %% [markdown]
# ### What's an "agent"?
#
# No universally agreed-upon definition, but:
# - A system that can take actions in an environment towards a goal
# - Ability to dynamically adapt logic on the fly in response to observations
# - Core contrast: agents vs. workflows/pipelines
#
# Agents:
# - Deep Research
# - Claude Code
# - Manus
#
# Non-agents:
# - pre-fetch RAG
# - fixed decision trees of LLMs
# - classifier-based routers (e.g. easy vs. hard questions to different LLMs)
#
# Reductive definition:
# - "LLM with tool calls in a while loop"
# - Must-read: [Building Effective Agents](https://www.anthropic.com/engineering/building-effective-agents) from Anthropic
#
#
# ![AGENTS](images/agent.webp)

# %% [markdown]
# ### What's an "environment"?
#
# Traditionally:
# - States, Actions, Environments, Transitions, Rewards
# Most basic example:
# - system prompt
# - goal
# - set of tools
#
# Simple version with no fancy libraries:
# - OpenAI client (can use any model/provider, or locally-hosted endpoint)
# - search tool + fetch tool

# %%
import os
from openai import OpenAI

model_name = "gpt-4.1"
base_url = "https://api.openai.com/v1"
client = OpenAI(base_url=base_url, api_key=os.getenv("OPENAI_API_KEY"))


system_prompt = """
You are a helpful assistant that can answer questions and help with tasks, such as drafting short research reports. Cite your sources when relevant. 

You have access to the following tools:

- search(query: str) -> str: Searches the web and returns summaries of top results.
- fetch(url: str) -> str: Fetches the content of a given URL and returns it as a markdown page.

You may call one tool per turn, for up to 10 turns, before giving your final answer.
In each turn, you should respond in the following format:

<think>
[your thoughts here]
</think>
<tool>
JSON with the following fields:
- name: The name of the tool to call
- args: A dictionary of arguments to pass to the tool (must be valid JSON)
</tool>

When you are done, give your final answer in the following format:

<answer>
[your final answer here]
</answer>
"""

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "What is the latest news in the NBA?"},
]

response = client.chat.completions.create(
    model=model_name,
    messages=messages, # type: ignore
)

response = response.choices[0].message.content # type: ignore
print(response)
# Out:
# <think>
# I will search for the latest news in the NBA to provide up-to-date information.
# </think>
# <tool>
# {"name": "search", "args": {"query": "latest NBA news"}}
# </tool>

# %%
# Basic search tool

def search(query: str) -> str:
    """Searches the web and returns summaries of top results.
    
    Args:
        query: The search query string

    Returns:
        Formatted string with bullet points of top 10 results, each with title, source, url, and brief summary

    Examples:
        {"query": "who invented the lightbulb"} -> ["Thomas Edison (1847-1931) - Inventor of the lightbulb", ...]
        {"query": "what is the capital of France"} -> ["Paris is the capital of France", ...]
        {"query": "when was the Declaration of Independence signed"} -> ["The Declaration of Independence was signed on July 4, 1776", ...]
    """

    try:
        from brave import Brave
        # set BRAVE_API_KEY in your environment
        brave = Brave()
        results = brave.search(q=query, count=10, raw=True) # type: ignore
        web_results = results.get('web', {}).get('results', []) # type: ignore
        
        if not web_results:
            return "No results found"

        summaries = []
        for r in web_results:
            if 'profile' not in r:
                continue
            header = f"{r['profile']['name']} ({r['profile']['long_name']})"
            title = r['title']
            snippet = r['description']
            url = r['url'] 
            summaries.append(f"•  {header}\n   {title}\n   {snippet}\n   {url}")

        return "\n\n".join(summaries)
    except Exception as e:
        return f"Error: {str(e)}"
# test
results = search("latest basketball scores")
print(results)
# Out:
# •  Flashscoreusa (flashscoreusa.com)
#    Basketball Livescore, Basketball Results | Flashscore - NBA, Euroleague, NCAA
#    <strong>Basketball</strong> livescore on Flashscore offers all the <strong>latest</strong> <strong>basketball</strong> results from more than 500+ <strong>basketball</strong> leagues all around the world including NBA, Euroleague, NCAA and more. Find all today&#x27;s/tonight&#x27;s <strong>basketball</strong> <strong>scores</strong> on Flashscore.
#    https://www.flashscoreusa.com/basketball/
#
# •  ESPN (Entertainment and Sports Programming Network)
#    NBA Scores, 2024-25 Season - ESPN
#    Live <strong>scores</strong> for every 2024-25 NBA season game on ESPN. Includes box <strong>scores</strong>, video highlights, play breakdowns and updated odds.
#    https://www.espn.com/nba/scoreboard
#
# •  Ncaa (ncaa.com)
#    NCAA college basketball scores | NCAA.com
#    Live college <strong>basketball</strong> <strong>scores</strong>, schedules and rankings from NCAA Division I men&#x27;s <strong>basketball</strong>.
#    https://www.ncaa.com/scoreboard/basketball-men/d1
#
# •  Livescore (livescore.in)
#    Livescore: Basketball Scores
#    <strong>Basketball</strong> livescore service provides <strong>basketball</strong> live <strong>scores</strong> for NBA, Eurolegue, ACB, Lega Basket and 400+ <strong>basketball</strong> competitions.
#    https://www.livescore.in/basketball/
#
# •  Aiscore (m.aiscore.com)
#    NBA Basketball Scores Today - AiScore
#    <strong>Basketball</strong> <strong>scores</strong> today on AiScore <strong>Basketball</strong> livescore. <strong>Basketball</strong> <strong>scores</strong> from NBA, NCAA , college, Euroleague, ACB, FIBA World Championship and live results from other <strong>basketball</strong> leagues.
#    https://m.aiscore.com/basketball
#
# •  Livescore (livescore.com)
#    Basketball Live Scores, Results & Fixtures | LiveScore
#    Click here for the <strong>latest</strong> <strong>Basketball</strong> <strong>scores</strong> &amp; results from around the world. <strong>Basketball</strong> <strong>scores</strong> from all the top leagues &amp; competitions including the <strong>latest</strong> news.
#    https://www.livescore.com/en/basketball/
#
# •  Sofascore (sofascore.com)
#    Basketball live results & schedule | Sofascore
#    Live <strong>basketball</strong> <strong>scores</strong> on Sofascore live <strong>score</strong>. Live <strong>scores</strong> from NBA, Euroleague, ACB, FIBA World Championship and live results from other <strong>basketball</strong> leagues.
#    https://www.sofascore.com/basketball
#
# •  Aiscore (m.aiscore.com)
#    Today's Basketball Matches Live - AiScore Basketball LiveScore
#    All the <strong>scores</strong>,results,and schedules for today&#x27;s games &amp; matches. All today&#x27;s games. ... UEFA Champions League 2024-25EPL Standings 2024-25Serie A Standings 2024-25LaLiga Standings 2024-25Head to HeadBundesliga Standings 2024-25Ligue 1 Standings 2024-25Primeira Liga Standings 2024-25Belgian Pro League Standings 2024-25FIFA World CupUEFA RankingsPrediction ... NBA Players Comparison <strong>Basketball</strong> ...
#    https://m.aiscore.com/today-matches/basketball
#
# •  24live (24live.com)
#    Basketball - Livescore scores, schedule and results - 24live
#    Football live <strong>scores</strong> on 24live livescore has live coverage from more than 800 world allround soccer leagues, tournaments and cups with live matches, match trackers, league tables, statistics and fixtures. Live matches from all football leagues have fast and precise updates for <strong>scores</strong>, halftime ...
#    https://24live.com/page/sport/match-list/basketball-6?lang=en
#
# •  365scores (365scores.com)
#    Basketball Games Today, Livescore and Standings
#    We cannot provide a description for this page right now
#    https://www.365scores.com/en-us/basketball

# %%
# fetch tool for URL contents

def fetch(url: str) -> str:
    """Fetches the content of a given URL and returns it as a markdown page.
    
    Args:
        url: The URL to fetch the content from

    Returns:
        A markdown page with the content of the URL.
    """
    import requests
    from markdownify import markdownify
    
    response = requests.get(url)
    response.raise_for_status()
    return markdownify(response.text)
content = fetch("https://www.flashscoreusa.com/basketball/")
print(content)
# Out:
# Basketball Livescore, Basketball Results | Flashscore - NBA, Euroleague, NCAA
#
#
#
#
# Basketball Livescore, Basketball Results, NBA, Euroleague, NCAA
# ===============================================================
#
#
#
# ![](https://static.flashscore.com/res/_fs/image/2_others/bg.png)
#
# [Scores](/)
# [News](/news/)
#
#
#
#
# [Favorites](/favorites/)
#
# [Soccer](/)
# [Tennis](/tennis/)
# [Golf](/golf/)
# [Football](/football/)
# [Basketball](/basketball/)
# [Baseball](/baseball/)
# [Hockey](/hockey/)
#
# [Aussie rules](/aussie-rules/)
# [Badminton](/badminton/)
# [Baseball](/baseball/)
# [Basketball](/basketball/)
# [Beach volleyball](/beach-volleyball/)
# [Boxing](/boxing/)
# [Cricket](/cricket/)
# [Cycling](/cycling/)
# [Darts](/darts/)
# [eSports](/esports/)
# [Field hockey](/field-hockey/)
# [Football](/football/)
# [Futsal](/futsal/)
# [Golf](/golf/)
# [Hockey](/hockey/)
# [Horse racing](/horse-racing/)
# [MMA](/mma/)
# [Motorsport](/motorsport/)
# [Rugby League](/rugby-league/)
# [Rugby Union](/rugby-union/)
# [Snooker](/snooker/)
# [Soccer](/soccer/)
# [Table tennis](/table-tennis/)
# [Team handball](/team-handball/)
# [Tennis](/tennis/)
# [Volleyball](/volleyball/)
# [Water polo](/water-polo/)
# [Winter Sports](/winter-sports/)
#
# AD
#
# [Basketball](/basketball/)
# --------------------------
#
# Loading...
#
# Pinned Leagues
#
# My Teams
#
# [Albania](/basketball/albania/)
# [Argentina](/basketball/argentina/)
# [Australia](/basketball/australia/)
# [Austria](/basketball/austria/)
# [Bahrain](/basketball/bahrain/)
# [Belarus](/basketball/belarus/)
# [Belgium](/basketball/belgium/)
# [Bolivia](/basketball/bolivia/)
# [Bosnia and Herzegovina](/basketball/bosnia-and-herzegovina/)
# [Brazil](/basketball/brazil/)
# [Bulgaria](/basketball/bulgaria/)
# [Canada](/basketball/canada/)
# [Canadian Elite Basketball League](/basketball/canada/canadian-elite-basketball-league/)
# [Chile](/basketball/chile/)
# [China](/basketball/china/)
# [Colombia](/basketball/colombia/)
# [Croatia](/basketball/croatia/)
# [Cyprus](/basketball/cyprus/)
# [Czech Republic](/basketball/czech-republic/)
# [Denmark](/basketball/denmark/)
# [Dominican Republic](/basketball/dominican-republic/)
# [Estonia](/basketball/estonia/)
# [Finland](/basketball/finland/)
# [France](/basketball/france/)
# [LNB](/basketball/france/lnb/)
# [Georgia](/basketball/georgia/)
# [Germany](/basketball/germany/)
# [Greece](/basketball/greece/)
# [Hong Kong](/basketball/hong-kong/)
# [Hungary](/basketball/hungary/)
# [Iceland](/basketball/iceland/)
# [Indonesia](/basketball/indonesia/)
# [Iran](/basketball/iran/)
# [Ireland](/basketball/ireland/)
# [Israel](/basketball/israel/)
# [Italy](/basketball/italy/)
# [Lega A](/basketball/italy/lega-a/)
# [Japan](/basketball/japan/)
# [Jordan](/basketball/jordan/)
# [Kazakhstan](/basketball/kazakhstan/)
# [Kosovo](/basketball/kosovo/)
# [Latvia](/basketball/latvia/)
# [Lebanon](/basketball/lebanon/)
# [Lithuania](/basketball/lithuania/)
# [Luxembourg](/basketball/luxembourg/)
# [Mexico](/basketball/mexico/)
# [Montenegro](/basketball/montenegro/)
# [Netherlands](/basketball/netherlands/)
# [New Zealand](/basketball/new-zealand/)
# [North Macedonia](/basketball/north-macedonia/)
# [Norway](/basketball/norway/)
# [Paraguay](/basketball/paraguay/)
# [Philippines](/basketball/philippines/)
# [Poland](/basketball/poland/)
# [Portugal](/basketball/portugal/)
# [Puerto Rico](/basketball/puerto-rico/)
# [Qatar](/basketball/qatar/)
# [Romania](/basketball/romania/)
# [Russia](/basketball/russia/)
# [Saudi Arabia](/basketball/saudi-arabia/)
# [Serbia](/basketball/serbia/)
# [Singapore](/basketball/singapore/)
# [Slovakia](/basketball/slovakia/)
# [Slovenia](/basketball/slovenia/)
# [South Korea](/basketball/south-korea/)
# [Spain](/basketball/spain/)
# [ACB](/basketball/spain/acb/)
# [Sweden](/basketball/sweden/)
# [Switzerland](/basketball/switzerland/)
# [Taiwan](/basketball/taiwan/)
# [Tajikistan](/basketball/tajikistan/)
# [Thailand](/basketball/thailand/)
# [Turkey](/basketball/turkey/)
# [Super Lig](/basketball/turkey/super-lig/)
# [Turkmenistan](/basketball/turkmenistan/)
# [Ukraine](/basketball/ukraine/)
# [United Kingdom](/basketball/united-kingdom/)
# [Uruguay](/basketball/uruguay/)
# [USA](/basketball/usa/)
# [NBA](/basketball/usa/nba/)
# [Venezuela](/basketball/venezuela/)
# [Vietnam](/basketball/vietnam/)
# [Africa](/basketball/africa/)
# [Asia](/basketball/asia/)
# [Australia & Oceania](/basketball/australia-oceania/)
# [Europe](/basketball/europe/)
# [EuroBasket](/basketball/europe/eurobasket/)
# [Euroleague](/basketball/europe/euroleague/)
# [Eurocup](/basketball/europe/eurocup/)
# [Champions League](/basketball/europe/champions-league/)
# [North America](/basketball/north-america/)
# [South America](/basketball/south-america/)
# [World](/basketball/world/)
# [World Cup](/basketball/world/world-cup/)
# [Olympic Games](/basketball/world/olympic-games/)
#
# Basketball livescore on Flashscore offers all the latest basketball results from more than 500+ basketball leagues and tournaments all around the world including the most famous [NBA](/basketball/usa/nba/), [Euroleague](/basketball/europe/euroleague/), [NCAA](/basketball/usa/ncaa/). Follow all the latest basketball results on Flashscore where you can find detailed match statistics (field goals/free throws %, rebounds, blocks, turnovers, personal fouls etc.), player statistics (points, rebounds, assists, minutes played etc.), odds comparison, H2H, lineups, video highlights, news or point by point match history. Find all today's/tonight's basketball scores on Flashscore. The basketball livescore service is real time, you don't need to refresh it.
# **NBA live** on Flashscore! Upcoming matches: 5/30 [Indiana Pacers - New York Knicks](/h2h/basketball/indiana-pacers-YPohMUTt/new-york-knicks-WCNO4nbt/). Follow NBA live scores, [results](/basketball/usa/nba/results/), [fixtures](/basketball/usa/nba/fixtures/) and [NBA standings](/basketball/usa/nba/results/) or team pages (e.g. [Boston Celtics](/team/boston-celtics/KYD9hVEm/), [Golden State Warriors](/team/golden-state-warriors/SxUtXqch/) ...).
#
# Show more
#
# [SOCCER](https://www.flashscoreusa.com)
#
# [MLS 2025](https://www.flashscoreusa.com/soccer/usa/mls/)
#
# [CONCACAF Champions Cup](https://www.flashscoreusa.com/soccer/north-america/concacaf-champions-cup/)
#
# [Liga MX](https://www.flashscoreusa.com/soccer/mexico/liga-mx/)
#
# [UEFA Champions League](https://www.flashscoreusa.com/soccer/europe/champions-league/)
#
# [Premier League](https://www.flashscoreusa.com/soccer/england/premier-league/)
#
# [LaLiga](https://www.flashscoreusa.com/soccer/spain/laliga/)
#
# [Serie A](https://www.flashscoreusa.com/soccer/italy/serie-a/)
#
# [Club World Cup 2025](https://www.flashscoreusa.com/soccer/world/fifa-club-world-cup/)
#
# [CWC 2025 Fixtures](https://www.flashscoreusa.com/soccer/world/fifa-club-world-cup/fixtures/)
#
# [CWC 2025 group standings](https://www.flashscoreusa.com/soccer/world/fifa-club-world-cup/standings/)
#
# [OTHER SPORTS](https://www.flashscoreusa.com)
#
# [NBA Scores](https://www.flashscoreusa.com/basketball/usa/nba/)
#
# [NBA News](https://www.flashscoreusa.com/news/nba/IBmris38CdnS0XT8/)
#
# [NHL News](https://www.flashscoreusa.com/news/nhl/G2Op923tCdnS0XT8/)
#
# [NHL Scores](https://www.flashscoreusa.com/nhl/)
#
# [MLB 2025](https://www.flashscoreusa.com/baseball/usa/mlb/)
#
# [Golf scores](https://www.flashscoreusa.com/golf/)
#
# [PGA Tour Calendar 2025](https://www.flashscoreusa.com/golf/calendar/pga/)
#
# [Hockey World Championship](https://www.flashscoreusa.com/hockey/world/world-championship/)
#
# [Team USA](https://www.flashscoreusa.com/team/usa/GYgp4SO3/)
#
# [Team Canada](https://www.flashscoreusa.com/team/canada/dSsR389c/)
#
# [LIVESCORE](https://www.flashscoreusa.com)
#
# [Khachanov - Paul](/h2h/tennis/khachanov-karen-4bNPtZT5/paul-tommy-pd3ye1BS/)
#
# [Shelton - Gigante](/h2h/tennis/shelton-ben-QNuG0Gzb/gigante-matteo-r3iKpV0F/)
#
# [Vondrousova - Pegula](/h2h/tennis/vondrousova-marketa-EgKYrSR5/pegula-jessica-KdojxrAR/)
#
# [Bouzkova - Gauff](/h2h/tennis/bouzkova-marie-WMS3AdAb/gauff-coco-f5BXmEH6/)
#
# [Griekspoor - Quinn](/h2h/tennis/griekspoor-tallon-f3zfMU5i/quinn-ethan-fDEtnFgg/)
#
# [Panathinaikos - Olympiacos](/h2h/basketball/panathinaikos-bqRyXX9C/olympiacos-piraeus-ptNXXDf6/)
#
# [Turk Telekom - Fenerbahce](/h2h/basketball/turk-telekom-xzhkYoHf/fenerbahce-rDhoZR1l/)
#
# [Los Angeles FC - Club America](/h2h/soccer/los-angeles-fc-txUJt9AR/club-america-vyrswtJm/)
#
# [Olympiacos - Panathinaikos](/h2h/basketball/olympiacos-piraeus-ptNXXDf6/panathinaikos-bqRyXX9C/)
#
# [New York Knicks - Indiana Pacers](/h2h/basketball/new-york-knicks-WCNO4nbt/indiana-pacers-YPohMUTt/)
#
# [SOCCER SCORES](https://www.flashscoreusa.com)
#
# [USA W - China W](/h2h/soccer/usa-KQv9BO32/china-IFHViN7N/)
#
# [USA W - Jamaica W](/h2h/soccer/usa-KQv9BO32/jamaica-IZbNBEZ5/)
#
# [USA - Turkey](/h2h/soccer/usa-fuitL4CF/turkey-QeijuHo5/)
#
# [Hong Kong - Manchester Utd](/h2h/soccer/hong-kong-lhTYF4Aj/manchester-united-ppjDR086/)
#
# [PSG - Inter](/h2h/soccer/psg-CjhkPw0k/inter-Iw7eKK25/)
#
# [Los Angeles FC - Club America](/h2h/soccer/los-angeles-fc-txUJt9AR/club-america-vyrswtJm/)
#
# [FC Cincinnati - DC United](/h2h/soccer/fc-cincinnati-8btog05R/dc-united-O6hjfSXE/)
#
# [Inter Miami - Columbus Crew](/h2h/soccer/inter-miami-0AheRyBg/columbus-crew-pQ8rarA7/)
#
# [Los Angeles Galaxy - Real Salt Lake](/h2h/soccer/los-angeles-galaxy-U3ebh62R/real-salt-lake-W0ealpQl/)
#
# [Pittsburgh - Rhode Island](/h2h/soccer/pittsburgh-riverhounds-trYG3CIh/rhode-island-EabuZlYo/)
#
# Hockey Scores
#
# [Dallas Stars - Edmonton Oilers](/h2h/hockey/dallas-stars-vVAvnIuC/edmonton-oilers-Mg0qoxeI/)
#
# [Laval Rocket - Charlotte Checkers](/h2h/hockey/laval-rocket-84h1bFyQ/charlotte-checkers-2TnCvGFs/)
#
# [Abbotsford Canucks - Texas Stars](/h2h/hockey/abbotsford-canucks-jcivLWO0/texas-stars-nT23xfgH/)
#
# [Charlotte Checkers - Laval Rocket](/h2h/hockey/charlotte-checkers-2TnCvGFs/laval-rocket-84h1bFyQ/)
#
# [Texas Stars - Abbotsford Canucks](/h2h/hockey/texas-stars-nT23xfgH/abbotsford-canucks-jcivLWO0/)
#
# FlashscoreUSA.com
#
# [Terms of Use](/terms-of-use/)
#
# [Privacy policy](/privacy-policy/)
#
# [GDPR and Journalism](/gdpr/)
#
# [Advertise](/advertise/)
#
# [Contact](/contact/)
#
# [Mobile](/mobile/)
#
# [Live Scores](/live-scores/)
#
# [Recommended Sites](/recommended/)
#
# [FAQ](/faq/)
#
# Follow us
#
# [Facebook](https://www.facebook.com/Flashscorecom/)
#
# [X](https://twitter.com/flashscorecom)
#
# [Instagram](https://www.instagram.com/flashscoreofficial/)
#
# [TikTok](https://tiktok.com/@flashscorecom)
#
# Mobile applications
#
# Our mobile app is optimized for your phone. Download it now for free!
#
# [![App Store](https://static.flashscore.com/res/_fs/image/9_stores/apple/en.svg)](https://apps.apple.com/app/id766443283?mt=8 "iPhone/iPad application")
# [![App Store](https://static.flashscore.com/res/_fs/image/9_stores/google/en.svg)](https://play.google.com/store/apps/details?id=eu.livesport.flashscoreusa_com "Android application")
# [![App Store](https://static.flashscore.com/res/_fs/image/9_stores/huawei/en.svg)](https://appgallery.huawei.com/app/C101497479?sharePrepath=ag)
#
# [Lite version](http://m.flashscoreusa.com/)
#
# Gamble Responsibly. [Gambling Therapy](http://www.gamblingtherapy.org/). 18+
#
# Copyright © 2024-25 FlashscoreUSA.com
#
# Set privacy

# %%
# basic tool parsing -- universal but less robust, use instructor/outlines/API-provider parsing for more anything production-grade
import re
import json

def parse_thinking_from_response(response: str) -> str | None:
    """Parse a thinking from a response."""
    thinking = re.search(r'<think>(.*?)</think>', response, re.DOTALL)
    if thinking:
        return thinking.group(1)
    return None

def parse_tool_from_response(response: str) -> dict | None:
    """Parse a tool from a response."""
    tool_call = re.search(r'<tool>(.*?)</tool>', response, re.DOTALL)
    if tool_call:
        return json.loads(tool_call.group(1))
    return None

def parse_answer_from_response(response: str) -> str | None:
    """Parse an answer from a response."""
    answer = re.search(r'<answer>(.*?)</answer>', response, re.DOTALL)
    if answer:
        return answer.group(1)
    return None

def call_tool(tool_call: dict) -> str:
    """Call a tool with the given tool call."""
    if tool_call['name'] == 'search':
        return search(tool_call['args']['query'])
    elif tool_call['name'] == 'fetch':
        return fetch(tool_call['args']['url'])
    else:
        return f"Error: Tool {tool_call['name']} not found"
    
# test
tool_call = {"name": "search", "args": {"query": "latest basketball scores"}}


example_response = """
<think>
I'll do a web search to retrieve the most recent news headlines and updates related to the NBA.
</think>
<tool>
{"name": "search", "args": {"query": "latest NBA news"}}
</tool>
"""

tool_call = parse_tool_from_response(example_response) # type: ignore
print(tool_call)
# Out:
# {'name': 'search', 'args': {'query': 'latest NBA news'}}

# %%
tool_result = call_tool(tool_call) # type: ignore
print(tool_result)
# Out:
# •  NBA (nba.com)
#    NBA News - Latest team, player and league news | NBA.com
#    <strong>NBA</strong> <strong>News</strong>: Your source of the most updated official <strong>NBA</strong> <strong>news</strong>. Stay current on the league, team and player <strong>news</strong>, scores, stats, standings from <strong>NBA</strong>.
#    https://www.nba.com/news
#
# •  ESPN (Entertainment and Sports Programming Network)
#    NBA on ESPN - Scores, Stats and Highlights
#    Visit ESPN for <strong>NBA</strong> live scores, video highlights and <strong>latest</strong> <strong>news</strong>. Stream games on ESPN and play Fantasy Basketball.
#    https://www.espn.com/nba/
#
# •  NBA (nba.com)
#    The official site of the NBA for the latest NBA Scores, Stats & News. | NBA.com
#    Follow the action on <strong>NBA</strong> scores, schedules, stats, <strong>news</strong>, teams, and players. Buy tickets or watch the games anywhere with <strong>NBA</strong> League Pass.
#    https://www.nba.com/
#
# •  Cbssports (cbssports.com)
#    NBA Basketball - News, Scores, Stats, Standings, and Rumors - National Basketball Association - CBSSports.com
#    CBS Sports has the <strong>latest</strong> <strong>NBA</strong> Basketball <strong>news</strong>, live scores, player stats, standings, fantasy games, and projections.
#    https://www.cbssports.com/nba/
#
# •  NBA (nba.com)
#    Top Stories | NBA.com
#    Does your local basketball court deserve an upgrade? Submit your story for the chance to win a full-court renovation · Tyrese Haliburton powers the Pacers past the Knicks with an unprecedented performance. Plus, an elimination Game 5 tonight in OKC
#    https://www.nba.com/news/category/top-stories
#
# •  RealGM (basketball.realgm.com)
#    NBA News, NBA Rumors, Trades, Free Agency - RealGM
#    With a dearth of available cap space in the <strong>NBA</strong> just as the league&#x27;s new media rights deals will increase the salary cap in the coming years, there are a number of teams with title ambitions who must enter the trade market to make meaningful changes.
#    https://basketball.realgm.com/nba/news
#
# •  Yahoo! (sports.yahoo.com)
#    NBA News, Video, Rumors, Scores, Stats, Standings - Yahoo Sports
#    The Thunder were in a different weight class that the Timberwolves and are now <strong>NBA</strong> Finals-bound.
#    https://sports.yahoo.com/nba/
#
# •  Bleacherreport (bleacherreport.com)
#    NBA | NBA News, Scores, Highlights, Stats, Standings, and Rumors | Bleacher Report
#    Be the best <strong>NBA</strong> fan you can be with Bleacher Report. Keep up with the <strong>latest</strong> storylines, expert analysis, highlights, scores and more.
#    https://bleacherreport.com/nba
#
# •  HoopsHype (hoopshype.com)
#    NBA Rumors and News | HoopsHype
#    Get the <strong>latest</strong> <strong>news</strong> on free agency, trades, salaries and more on HoopsHype Rumors.
#    https://hoopshype.com/rumors/
#
# •  Sportspyder (sportspyder.com)
#    The Latest NBA News
#    We cannot provide a description for this page right now
#    https://sportspyder.com/sports/nba/news

# %%
# agent loop
final_answer = ""

question = "What is the latest news in the NBA? Give me a 3 paragraph report."
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question},
]

turns = 0
while True:
    turns += 1
    retries = 0 
    while retries < 5:
        try:
            response = client.chat.completions.create(
                model=model_name,
                messages=messages, # type: ignore
            )
            response = response.choices[0].message.content # type: ignore
            # parse for thinking, tool call, and/or answer 
            maybe_thinking = parse_thinking_from_response(response) # type: ignore
            maybe_tool_call = parse_tool_from_response(response) # type: ignore
            maybe_answer = parse_answer_from_response(response) # type: ignore
            if maybe_tool_call or maybe_answer:
                break
        except Exception as e:
            print(f"Error: {e}")
            retries += 1
    print("=== Turn", turns, "===")
    if maybe_thinking: # type: ignore
        thinking = maybe_thinking.strip()
        print(f"Thinking: {thinking}")
    if maybe_tool_call: # type: ignore
        tool_call = maybe_tool_call
        tool_result = call_tool(tool_call)
        print(f"Tool call: {tool_call}")
        print(f"Tool result: {tool_result[:100]}")
        messages.append({"role": "user", "content": tool_result})
    elif maybe_answer: # type: ignore
        final_answer = maybe_answer
        break
    else:
        print("Error: No tool call or answer found")
        break
# Out:
# === Turn 1 ===
# Thinking: I should search for the latest NBA news to provide an up-to-date and accurate 3-paragraph report summarizing key happenings in the league.
# Tool call: {'name': 'search', 'args': {'query': 'latest NBA news'}}
# Tool result: •  NBA (nba.com)
#    NBA News - Latest team, player and league news | NBA.com
#    <strong>NBA</strong>
# === Turn 2 ===
# Thinking: To provide an up-to-date and comprehensive 3-paragraph report on the latest NBA news, I will begin by checking NBA.com's official news page for recent headlines and top stories.
# Tool call: {'name': 'fetch', 'args': {'url': 'https://www.nba.com/news'}}
# Tool result: NBA News - Latest team, player and league news | NBA.com
#
# Navigation Toggle[![NBA Logo](https://cdn.
# === Turn 3 ===
# Thinking: The latest NBA news centers around the ongoing playoffs, with the Oklahoma City Thunder advancing to the NBA Finals after defeating the Minnesota Timberwolves in five games. Tyrese Haliburton's impressive performance and historic triple-double have also propelled the Indiana Pacers to a 3-1 lead over the New York Knicks in the Eastern Conference Finals. Additionally, there are notable updates on personnel, including Russell Westbrook undergoing right-hand surgery and Denver introducing David Adelman as their new head coach. I will synthesize this information into a concise three-paragraph report.

# %%
print(f"Final answer: {final_answer}")
# Out:
# Final answer:
# The NBA Playoffs are reaching a dramatic conclusion as the Oklahoma City Thunder have secured their place in the NBA Finals by defeating the Minnesota Timberwolves 4-1 in the Western Conference Finals. The Thunder's success was built on their depth, defense, and the continued star performances of Shai Gilgeous-Alexander, Jalen Williams, and rookie standout Chet Holmgren. Oklahoma City closed out the series with a dominant performance, showcasing their readiness to contend for their first championship since relocating from Seattle.
#
# Meanwhile, the Eastern Conference Finals are turning into a showcase for Indiana Pacers guard Tyrese Haliburton, who delivered a historic Game 4 triple-double—posting at least 30 points, 15 assists, and 10 rebounds with no turnovers, a feat never before accomplished in NBA playoff history. His efforts, alongside key moments from teammate Aaron Nesmith, have pushed the Pacers to a commanding 3-1 series lead over the New York Knicks, putting Indiana on the brink of its first NBA Finals appearance in decades.
#
# Off the court, there have been significant developments as well. Denver Nuggets guard Russell Westbrook announced he underwent surgery to repair two breaks in his right hand, an injury sustained during the season. The Nuggets also introduced new head coach David Adelman, who discussed plans for player conditioning and strategic adjustments heading into the offseason. Across the league, attention now turns to pivotal playoff games and the upcoming NBA Draft, with top prospects like Cooper Flagg garnering headlines at the combine.
# (Source: [NBA.com Latest News](https://www.nba.com/news))

# %%
### Models as tools

def ask_model(question: str, url: str) -> str:
    """Ask a model a question about a URL and return the answer."""

    fetch_result = fetch(url)
    system_prompt = "You are a helpful assistant that can answer questions about a given URL."
    prompt = f"""
    Here is the content of the URL {url}:
    {fetch_result}

    Here is the question:
    {question}
    """
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": prompt},
    ]
    # ask model to answer question about url
    answer = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=messages, # type: ignore
    )
    return answer.choices[0].message.content # type: ignore

# test
question = "What is the latest news in the NBA?."
url = "https://www.nba.com/news"
answer = ask_model(question, url)
print(answer)
# Out:
# The latest news in the NBA includes:
#
# 1. "5 takeaways: Thunder finish Wolves in 5" – Oklahoma City Thunder advance to the NBA Finals by defeating the Minnesota Timberwolves in 5 games. The Thunder showed star power, defense, and depth in an emphatic close-out win. (8 hours ago)
#
# 2. "4 stats to know for Knicks-Pacers Game 5" – Indiana's offense has been the driving force behind its 3-1 series lead over New York Knicks as the two teams prepare for Game 5.
#
# 3. "5 key stats from OKC's run to 2025 NBA Finals" – The Thunder have amassed impressive stats on their way to the NBA Finals.
#
# 4. "Thunder showing blueprint for success" – Isiah Thomas praises the Thunder's approach and suggests the Timberwolves could learn from their success.
#
# 5. Denver Nuggets' new coach David Adelman reveals offseason plans, focusing on team conditioning. (21 hours ago)
#
# 6. Tyrese Haliburton posted a historic triple-double in Game 4, helping put the Pacers on the brink with their win over the Knicks. (18 hours ago)
#
# 7. Shaqtin' A Fool: Best of 2024-25 season highlights notable moments such as Nikola Jokić's defense and Ben Simmons' mistakes. (May 28, 2025)
#
# 8. Cooper Flagg at the NBA Draft Combine video feature. (May 22, 2025)
#
# 9. Shai Gilgeous-Alexander named the 2024-25 Kia NBA MVP along with other major regular-season award winners. (May 21, 2025)
#
# Additionally, recent highlights include the Thunder clinching the Finals berth for the first time in 13 years, and the Pacers vs. Knicks series with notable performances and Game 5 elimination scenarios. There is also news on Nuggets' Russell Westbrook having undergone surgery on his right hand.
#
# For more in-depth and up-to-date details, NBA.com/news is the place to visit.

# %%
# 

import os
from openai import OpenAI

model_name = "gpt-4.1"
base_url = "https://api.openai.com/v1"
client = OpenAI(base_url=base_url, api_key=os.getenv("OPENAI_API_KEY"))

system_prompt = """
You are a helpful assistant that can answer questions and help with tasks, such as drafting short research reports. Cite your sources when relevant. 

You have access to the following tools:

- search(query: str) -> str: Searches the web and returns summaries of top results.
- ask_model(question: str, url: str) -> str: Ask an AI helper model a question about a given URL and return the answer.

You may call one tool per turn, for up to 10 turns, before giving your final answer.


In each turn, you should respond in the following format:

<think>
[your thoughts here]
</think>
<tool>
JSON with the following fields:
- name: The name of the tool to call
- args: A dictionary of arguments to pass to the tool (must be valid JSON)
</tool>

When you are done, give your final answer in the following format:

<answer>
[your final answer here]
</answer>
"""

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "What is the latest news in the NBA?"},
]

response = client.chat.completions.create(
    model=model_name,
    messages=messages, # type: ignore
)

response = response.choices[0].message.content # type: ignore
print(response)
# Out:
# <think>
# I will perform a web search to find the latest news and developments in the NBA, focusing on today's headlines and updates.
# </think>
# <tool>
# {"name": "search", "args": {"query": "latest NBA news"}}
# </tool>

# %%
# updated call_tool
def call_tool(tool_call: dict) -> str:
    """Call a tool with the given tool call."""
    if tool_call['name'] == 'search':
        return search(tool_call['args']['query'])
    elif tool_call['name'] == 'fetch':
        return fetch(tool_call['args']['url'])
    elif tool_call['name'] == 'ask_model':
        return ask_model(tool_call['args']['question'], tool_call['args']['url'])
    else:
        return f"Error: Tool {tool_call['name']} not found"
    
# agent loop
final_answer = ""

question = "What is the latest news in the NBA? Give me a 3 paragraph report."
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question},
]

turns = 0
while True:
    turns += 1
    retries = 0 
    while retries < 5:
        try:
            response = client.chat.completions.create(
                model=model_name,
                messages=messages, # type: ignore
            )
            response = response.choices[0].message.content # type: ignore
            # parse for thinking, tool call, and/or answer 
            maybe_thinking = parse_thinking_from_response(response) # type: ignore
            maybe_tool_call = parse_tool_from_response(response) # type: ignore
            maybe_answer = parse_answer_from_response(response) # type: ignore
            if maybe_thinking or maybe_tool_call or maybe_answer:
                break
        except Exception as e:
            print(f"Error: {e}")
            retries += 1
    print("=== Turn", turns, "===")
    if maybe_thinking: # type: ignore
        thinking = maybe_thinking.strip()
        print(f"Thinking: {thinking}")
    if maybe_tool_call: # type: ignore
        tool_call = maybe_tool_call
        tool_result = call_tool(tool_call)
        print(f"Tool call: {tool_call}")
        print(f"Tool result: {tool_result[:100]}")
        messages.append({"role": "user", "content": tool_result})
    elif maybe_answer: # type: ignore
        final_answer = maybe_answer
        break
    else:
        print("Error: No tool call or answer found")
        break
# Out:
# === Turn 1 ===
# Thinking: To provide a current, accurate, and succinct three-paragraph report on the latest NBA news, I will search for up-to-date summaries from reputable sports news sources.
# Tool call: {'name': 'search', 'args': {'query': 'latest NBA news'}}
# Tool result: •  NBA (nba.com)
#    NBA News - Latest team, player and league news | NBA.com
#    <strong>NBA</strong>
# === Turn 2 ===
# Thinking: To write a 3-paragraph report on the latest NBA news, I need to gather updates on current games, player performances, and any major events from today. The most authoritative and updated sources would be NBA.com, ESPN, and possibly Bleacher Report. I will start by checking the latest top stories from NBA.com.
# Tool call: {'name': 'ask_model', 'args': {'question': 'What are the latest NBA news stories and updates as of today? Summarize the top headlines and key events.', 'url': 'https://www.nba.com/news/category/top-stories'}}
# Tool result: As of today, the latest NBA news stories and updates include the following top headlines and key eve
# === Turn 3 ===
# Thinking: To provide an accurate and up-to-date 3-paragraph NBA news report, I will synthesize the headlines and details you've shared, organizing them by playoff updates, standout performances, and other league news. I'll cite sources such as NBA.com and ESPN due to their reliability.
# Tool call: {'name': 'search', 'args': {'query': 'NBA latest news and playoff updates May 29, 2024'}}
# Tool result: •  NBA (nba.com)
#    2025 NBA Playoffs: Full schedule and results | NBA.com
#    The <strong>NBA</stron
# === Turn 4 ===
# Thinking: I'll check the official NBA news feed to verify the latest developments, with a focus on the playoffs, Game 5 of the Eastern Conference Finals, and significant player achievements for a well-balanced, up-to-date 3-paragraph news report.
# Tool call: {'name': 'ask_model', 'args': {'question': 'What are the most important updates and headlines from today in the NBA, especially regarding the Conference Finals and noteworthy player performances?', 'url': 'https://www.nba.com/news'}}
# Tool result: The most important updates and headlines from today in the NBA, especially regarding the Conference
# === Turn 5 ===
# Thinking: I have gathered the latest key updates and news from the NBA today, including Conference Finals outcomes, player highlights, and injury reports. For a concise 3-paragraph report, I should synthesize this information into a coherent summary, citing the main NBA.com news and playoff coverage as sources.
# Tool call: {'name': 'ask_model', 'args': {'question': 'Please provide a brief 3-paragraph report summarizing the latest NBA Conference Finals results, major player achievements, and notable headlines for today.', 'url': 'https://www.nba.com/news'}}
# Tool result: The latest NBA Conference Finals have been marked by the Oklahoma City Thunder advancing to the NBA
# === Turn 6 ===

# %%
print(f"Final answer: {final_answer}")
# Out:
# Final answer:
# The NBA Conference Finals are reaching an exciting peak, with the Oklahoma City Thunder clinching a berth in the NBA Finals after a commanding 4-1 series win over the Minnesota Timberwolves. Oklahoma City’s return to the Finals for the first time in over a decade has been built on star power, elite defense, and enviable team chemistry. Shai Gilgeous-Alexander, recently named the 2024-25 Kia NBA MVP, has anchored their impressive run, while Jalen Williams’ breakout performances have provided crucial support throughout the playoffs.
#
# In the Eastern Conference, the Indiana Pacers hold a 3-1 series lead over the New York Knicks, thanks in large part to Tyrese Haliburton’s historic Game 4. Haliburton posted at least 30 points, 15 assists, and 10 rebounds with zero turnovers—a first in NBA playoff history—powering Indiana to the brink of an NBA Finals appearance. As the Pacers look to close out the series in a pivotal Game 5 at Madison Square Garden, the Knicks seek answers both offensively and defensively, facing elimination at home.
#
# Off the court, notable news includes Denver Nuggets guard Russell Westbrook undergoing right-hand surgery, and the introduction of new Nuggets coach David Adelman, who outlined an offseason focus on team conditioning and strategic adjustments. The NBA continues to build community engagement through initiatives like the “Every Court Has A Story” contest, which offers communities a chance to win a basketball court renovation. All eyes remain on the upcoming elimination games, player milestones, and the league’s evolving storylines as a new champion edges closer to being crowned.
# **Sources:** [NBA.com](https://www.nba.com/news), [ESPN NBA](https://www.espn.com/nba/), [NBA Playoffs 2025](https://www.nba.com/playoffs/2025)

# %% [markdown]
# ### MCP Crash Course
#
# TLDR: MCP is basically just function calling
#
# Why:
# - multiple function methods
# - client/server architecture, clients + servers can manage their own state
# - standardized interface, portability
# - both Python + Typescript servers supported (uvx, npx)
#     - also Java/Kotlin/C#/Swift SDKs, but less popular
#
# Getting Started:
# - MCP Server [docs](https://modelcontextprotocol.io/quickstart/server)
# - MCP Client [docs](https://modelcontextprotocol.io/quickstart/client)
# - example servers: [modelcontextprotocol/servers](https://github.com/modelcontextprotocol/servers)
# - Other repositories:
#     - [Smithery](https://smithery.ai/)
#     - [mcp.so](https://mcp.so/)
#     - [awesome-mcp-servers](https://github.com/punkpeye/awesome-mcp-servers)
#
#
# MCP Clients:
# - Claude Desktop
# - Claude Code
# - Cursor, Windsurf, other IDEs

# %% [markdown]
# ### Deep Research via Claude Code
#
# Claude Code is set up to be a code agent by default, but can also be used as a sandbox for other agentic workflows
#
# We just need:
# - tools
# - instructions
# - examples?
# - ability to refine via feedback

# %%
basic_prompt = """
Write a report about upcoming tech events in NYC. Save the report as a markdown file in the reports folder.
"""

# %% [markdown]
# ## COURSE DISCOUNT
#
# ### Use promo code 'LIGHTNING' for 20% off
#
# https://maven.com/will-brown-kyle-corbitt/agents-mcp-rl?promoCode=LIGHTNING
#
# - Course runs June 16 - July 4
# - Lectures on Tuesdays/Thursdays @ 5PM ET
# - Office hours throughout, more will be added
# - Lectures are recorded, can be watched async any time (including after the course)
# - Weekly take-home projects
# - Agents, MCP, Evals, Tool Calling, Reinforcement Learning, GRPO, and more
#
#
# ![PROMOCODE](images/lightning_qr.png)

# %% [markdown]
# ##
