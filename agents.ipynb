# %% [markdown]
# # Building Your Own AI Research Agent
#
#
# ### About Me
# - will brown from ai twitter (@willccbb)
# - research lead @ prime intellect
# - spent 2yrs @ morgan stanley doing LLM applications
# - did phd @ columbia on multi-agent learning theory
# - i work on agentic RL stuff (see [willccbb/verifiers](https://github.com/willccbb/verifiers) on github)
#
#
# ### About the Full Course (Production-Ready Agent Engineering: From MCP to RL)
# - runs june 16 - july 4
# - co-teaching with kyle corbitt (@corbtt), ceo of openpipe
# - agent stuff AND rl stuff
#     - two sides of the same coin
#     - course starts with practical
#     - builds towards RL finetuning for OSS models
#     - most patterns have analogues which can be applied to closed/API models
#
# ### Today's Lightning Lesson
# - Basic definitions
# - Function-calling and writing your own tools
# - MCP crash course
# - Connecting MCP servers to clients
# - Scaffolding a "deep research"

# %% [markdown]
# ### What's an "agent"?
#
# No universally agreed-upon definition, but:
# - A system that can take actions in an environment towards a goal
# - Ability to dynamically adapt logic on the fly in response to observations
# - Core contrast: agents vs. workflows/pipelines
#
# Agents:
# - Deep Research
# - Claude Code
# - Manus
#
# Non-agents:
# - pre-fetch RAG
# - fixed decision trees of LLMs
#
#
# Reductive definition:
# - "LLM with tool calls in a while loop"
# - Must-read: [Building Effective Agents](https://www.anthropic.com/engineering/building-effective-agents) from Anthropic
#
#
# ![AGENTS](images/agent.webp)

# %% [markdown]
# ### What's an "environment"?
#
# Most basic example:
# - system prompt
# - set of tools
#
# Simple version with no fancy libraries:
# - OpenAI client (can use any model/provider, or locally-hosted endpoint)
# - search tool + fetch tool

# %%
import os
from openai import OpenAI

model_name = "gpt-4.1"
base_url = "https://api.openai.com/v1"
client = OpenAI(base_url=base_url, api_key=os.getenv("OPENAI_API_KEY"))


system_prompt = """
You are a helpful assistant that can answer questions and help with tasks, such as drafting short research reports. Cite your sources when relevant. 

You have access to the following tools:

- search(query: str) -> str: Searches the web and returns summaries of top results.
- fetch(url: str) -> str: Fetches the content of a given URL and returns it as a markdown page.

You may call one tool per turn, for up to 10 turns, before giving your final answer.
In each turn, you should respond in the following format:

<think>
[your thoughts here]
</think>
<tool>
JSON with the following fields:
- name: The name of the tool to call
- args: A dictionary of arguments to pass to the tool (must be valid JSON)
</tool>

When you are done, give your final answer in the following format:

<answer>
[your final answer here]
</answer>
"""

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "What is the latest news in the NBA?"},
]

response = client.chat.completions.create(
    model=model_name,
    messages=messages, # type: ignore
)

response = response.choices[0].message.content # type: ignore
print(response)
# Out:
# <think>
# I will search for the latest NBA news headlines to provide a current summary.
# </think>
# <tool>
# {"name": "search", "args": {"query": "latest NBA news"}}
# </tool>

# %%
# Basic search tool

def search(query: str) -> str:
    """Searches the web and returns summaries of top results.
    
    Args:
        query: The search query string

    Returns:
        Formatted string with bullet points of top 10 results, each with title, source, url, and brief summary

    Examples:
        {"query": "who invented the lightbulb"} -> ["Thomas Edison (1847-1931) - Inventor of the lightbulb", ...]
        {"query": "what is the capital of France"} -> ["Paris is the capital of France", ...]
        {"query": "when was the Declaration of Independence signed"} -> ["The Declaration of Independence was signed on July 4, 1776", ...]
    """

    try:
        from brave import Brave
        # set BRAVE_API_KEY in your environment
        brave = Brave()
        results = brave.search(q=query, count=10, raw=True) # type: ignore
        web_results = results.get('web', {}).get('results', []) # type: ignore
        
        if not web_results:
            return "No results found"

        summaries = []
        for r in web_results:
            if 'profile' not in r:
                continue
            header = f"{r['profile']['name']} ({r['profile']['long_name']})"
            title = r['title']
            snippet = r['description']
            url = r['url'] 
            summaries.append(f"•  {header}\n   {title}\n   {snippet}\n   {url}")

        return "\n\n".join(summaries)
    except Exception as e:
        return f"Error: {str(e)}"
# test
results = search("latest basketball scores")
print(results)
# Out:
# •  Flashscoreusa (flashscoreusa.com)
#    Basketball Livescore, Basketball Results | Flashscore - NBA, Euroleague, NCAA
#    <strong>Basketball</strong> livescore on Flashscore offers all the <strong>latest</strong> <strong>basketball</strong> results from more than 500+ <strong>basketball</strong> leagues all around the world including NBA, Euroleague, NCAA and more. Find all today&#x27;s/tonight&#x27;s <strong>basketball</strong> <strong>scores</strong> on Flashscore.
#    https://www.flashscoreusa.com/basketball/
#
# •  ESPN (Entertainment and Sports Programming Network)
#    NBA Scores, 2024-25 Season - ESPN
#    Live <strong>scores</strong> for every 2024-25 NBA season game on ESPN. Includes box <strong>scores</strong>, video highlights, play breakdowns and updated odds.
#    https://www.espn.com/nba/scoreboard
#
# •  Ncaa (ncaa.com)
#    NCAA college basketball scores | NCAA.com
#    Live college <strong>basketball</strong> <strong>scores</strong>, schedules and rankings from NCAA Division I men&#x27;s <strong>basketball</strong>.
#    https://www.ncaa.com/scoreboard/basketball-men/d1
#
# •  Livescore (livescore.in)
#    Livescore: Basketball Scores
#    <strong>Basketball</strong> livescore service provides <strong>basketball</strong> live <strong>scores</strong> for NBA, Eurolegue, ACB, Lega Basket and 400+ <strong>basketball</strong> competitions.
#    https://www.livescore.in/basketball/
#
# •  Aiscore (m.aiscore.com)
#    NBA Basketball Scores Today - AiScore
#    <strong>Basketball</strong> <strong>scores</strong> today on AiScore <strong>Basketball</strong> livescore. <strong>Basketball</strong> <strong>scores</strong> from NBA, NCAA , college, Euroleague, ACB, FIBA World Championship and live results from other <strong>basketball</strong> leagues.
#    https://m.aiscore.com/basketball
#
# •  Livescore (livescore.com)
#    Basketball Live Scores, Results & Fixtures | LiveScore
#    Click here for the <strong>latest</strong> <strong>Basketball</strong> <strong>scores</strong> &amp; results from around the world. <strong>Basketball</strong> <strong>scores</strong> from all the top leagues &amp; competitions including the <strong>latest</strong> news.
#    https://www.livescore.com/en/basketball/
#
# •  Sofascore (sofascore.com)
#    Basketball live results & schedule | Sofascore
#    Live <strong>basketball</strong> <strong>scores</strong> on Sofascore live <strong>score</strong>. Live <strong>scores</strong> from NBA, Euroleague, ACB, FIBA World Championship and live results from other <strong>basketball</strong> leagues.
#    https://www.sofascore.com/basketball
#
# •  Aiscore (m.aiscore.com)
#    Today's Basketball Matches Live - AiScore Basketball LiveScore
#    All the <strong>scores</strong>,results,and schedules for today&#x27;s games &amp; matches. All today&#x27;s games. ... UEFA Champions League 2024-25EPL Standings 2024-25Serie A Standings 2024-25LaLiga Standings 2024-25Head to HeadBundesliga Standings 2024-25Ligue 1 Standings 2024-25Primeira Liga Standings 2024-25Belgian Pro League Standings 2024-25FIFA World CupUEFA RankingsPrediction ... NBA Players Comparison <strong>Basketball</strong> ...
#    https://m.aiscore.com/today-matches/basketball
#
# •  24live (24live.com)
#    Basketball - Livescore scores, schedule and results - 24live
#    Football live <strong>scores</strong> on 24live livescore has live coverage from more than 800 world allround soccer leagues, tournaments and cups with live matches, match trackers, league tables, statistics and fixtures. Live matches from all football leagues have fast and precise updates for <strong>scores</strong>, halftime ...
#    https://24live.com/page/sport/match-list/basketball-6?lang=en
#
# •  365scores (365scores.com)
#    Basketball Games Today, Livescore and Standings
#    We cannot provide a description for this page right now
#    https://www.365scores.com/en-us/basketball

# %%
# fetch tool for URL contents

def fetch(url: str) -> str:
    """Fetches the content of a given URL and returns it as a markdown page.
    
    Args:
        url: The URL to fetch the content from

    Returns:
        A markdown page with the content of the URL.
    """
    import requests
    from markdownify import markdownify
    
    response = requests.get(url)
    response.raise_for_status()
    return markdownify(response.text)
content = fetch("https://www.ncaa.com/scoreboard/basketball-men/d1")
print(content)
# Out:
# NCAA college basketball scores | NCAA.com
#
#
# [Skip to main content](#main-content)
#
# [View All Scores](#)
#
# ### TRENDING:
#
# ### Follow live
#
# [Women's College World Series begins](https://www.ncaa.com/live-updates/softball/d1/live-updates-2025-womens-college-world-series)
#
# [DIII softball finals](https://www.ncaa.com/liveschedule)
#
# [🏃‍♀️ DI track & field first rounds](https://www.ncaa.com/live-updates/trackfield-outdoor-women/d1/live-updates-2025-di-track-and-field-championships)
#
# [🤔 Toughest DI baseball regionals](https://www.ncaa.com/news/baseball/article/2025-05-28/toughest-regional-and-national-champion-picks-2025-ncaa-baseball-tournament)
#
# [NCAA.com](/)
#
# * [Live Video](/liveschedule)
# * Sports
#
#   ### Sports
#
#   #### Fall
#
#   + [Cross Country - Men](/sports/cross-country-men)
#   + [Cross Country - Women](/sports/cross-country-women)
#   + Cross Country
#
#     [MMen](/sports/cross-country-men)[WWomen](/sports/cross-country-women)
#   + [Field Hockey](/sports/fieldhockey)
#   + [Football](/sports/football)
#   + [Individual Tennis (DI) - Men](/sports/tennis-men)
#   + [Individual Tennis (DI) - Women](/sports/tennis-women)
#   + Individual Tennis (DI)
#
#     [MMen](/sports/tennis-men)[WWomen](/sports/tennis-women)
#   + [Soccer - Men](/sports/soccer-men)
#   + [Soccer - Women](/sports/soccer-women)
#   + Soccer
#
#     [MMen](/sports/soccer-men)[WWomen](/sports/soccer-women)
#   + [Volleyball - Women](/sports/volleyball-women)
#   + [Water Polo - Men](/sports/waterpolo-men)
#
#   #### Winter
#
#   + [Basketball - Men](/sports/basketball-men)
#   + [Basketball - Women](/sports/basketball-women)
#   + Basketball
#
#     [MMen](/sports/basketball-men)[WWomen](/sports/basketball-women)
#   + [Bowling](/sports/bowling)
#   + [Fencing](/sports/fencing)
#   + [Gymnastics - Men](/sports/gymnastics-men)
#   + [Gymnastics - Women](/sports/gymnastics-women)
#   + Gymnastics
#
#     [MMen](/sports/gymnastics-men)[WWomen](/sports/gymnastics-women)
#   + [Ice Hockey - Men](/sports/icehockey-men)
#   + [Ice Hockey - Women](/sports/icehockey-women)
#   + Ice Hockey
#
#     [MMen](/sports/icehockey-men)[WWomen](/sports/icehockey-women)
#   + [Rifle](/sports/rifle)
#   + [Skiing](/sports/skiing)
#   + [Swimming & Diving - Men](/sports/swimming-men)
#   + [Swimming & Diving - Women](/sports/swimming-women)
#   + Swimming & Diving
#
#     [MMen](/sports/swimming-men)[WWomen](/sports/swimming-women)
#   + [Track & Field (I) - Men](/sports/trackfield-indoor-men)
#   + [Track & Field (I) - Women](/sports/trackfield-indoor-women)
#   + Track & Field (I)
#
#     [MMen](/sports/trackfield-indoor-men)[WWomen](/sports/trackfield-indoor-women)
#   + [Wrestling](/sports/wrestling)
#
#   #### Spring
#
#   + [Baseball](/sports/baseball)
#   + [Beach Volleyball](/sports/beach-volleyball)
#   + [Golf - Men](/sports/golf-men)
#   + [Golf - Women](/sports/golf-women)
#   + Golf
#
#     [MMen](/sports/golf-men)[WWomen](/sports/golf-women)
#   + [Lacrosse - Men](/sports/lacrosse-men)
#   + [Lacrosse - Women](/sports/lacrosse-women)
#   + Lacrosse
#
#     [MMen](/sports/lacrosse-men)[WWomen](/sports/lacrosse-women)
#   + [Rowing](/sports/rowing)
#   + [Softball](/sports/softball)
#   + [Tennis - Men](/sports/tennis-men)
#   + [Tennis - Women](/sports/tennis-women)
#   + Tennis
#
#     [MMen](/sports/tennis-men)[WWomen](/sports/tennis-women)
#   + [Track & Field (O) - Men](/sports/trackfield-outdoor-men)
#   + [Track & Field (O) - Women](/sports/trackfield-outdoor-women)
#   + Track & Field (O)
#
#     [MMen](/sports/trackfield-outdoor-men)[WWomen](/sports/trackfield-outdoor-women)
#   + [Volleyball - Men](/sports/volleyball-men)
#   + [Water Polo - Women](/sports/waterpolo-women)
# * [Video](/video)
# * March Madness
#
#   ### March Madness
#
#   #### March Madness Live (DI MBB)
#
#   + - [Home](/march-madness-live/watch?cid=ncaa_mml_nav_men)
#     - [Scores](/march-madness-live/scores)
#     - [My Picks](/march-madness-live/bcg)
#     - [Official Bracket](/march-madness-live/bracket)
#
#   #### March Madness (DI WBB)
#
#   + - [Home](/womens-di-championship?mml=1&cid=ncaa_mml_nav_women)
#     - [Scores](/scoreboard/basketball-women/d1?mml=1)
#     - [My Picks](https://play.ncaa.com/dashboard/?tab=womens)
#     - [Official Bracket](/brackets/basketball-women/d1?mml=1)
#
#   + [March Madness Live (DI MBB)](/march-madness-live/watch?cid=ncaa_mml_nav_men)
#   + [March Madness (DI WBB)](/womens-di-championship?mml=1&cid=ncaa_mml_nav_women)
# * Schools
#
#   ### Trending Schools
#
#   All Schools
#
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/tampa.svg) Tampa](/schools/tampa)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/texas-tyler.svg) Texas at Tyler](/schools/texas-tyler)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/wash-jeff.svg) Wash. & Jeff.](/schools/wash-jeff)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/florida.svg) Florida](/schools/florida)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/texas.svg) Texas](/schools/texas)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/ucla.svg) UCLA](/schools/ucla)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/tennessee.svg) Tennessee](/schools/tennessee)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/ole-miss.svg) Mississippi](/schools/ole-miss)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/oklahoma.svg) Oklahoma](/schools/oklahoma)
#   + [![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/oregon.svg) Oregon](/schools/oregon)
#
# * Shop
#
#   ### Shop
#
#   + [Home](https://www.shopncaasports.com/?_s=bm_ncaashop_shop_dropdown&utm_source=ncaashop&utm_medium=referral&utm_term=ncaashop_shop_drop)
#   + [NCAA Championships Gear](https://www.shopncaasports.com/c-1940?_s=bm_ncaashop_championship_gear_dropdown&utm_source=ncaashop&utm_medium=referral&utm_term)
#   + [Men’s Gear](https://www.shopncaasports.com/mens/ga-1?_s=bm_ncaashop_mens_gear_dropdown&utm_source=ncaashop&utm_medium=referral&utm_term=ncaa)
#   + [Women’s Gear](https://www.shopncaasports.com/womens/ga-2?_s=bm_ncaashop_womens_gear_dropdown&utm_source=ncaashop&utm_medium=referral&utm_term=)
#   + [Kids Gear](https://www.shopncaasports.com/kids/ga-3?_s=bm_ncaashop_kids_gear_dropdown&utm_source=ncaashop&utm_medium=referral&utm_term=ncaa)
#   + [T-Shirts](https://www.shopncaasports.com/t-shirts/d-8022?_s=bm_ncaashop_tshirts_dropdown&utm_source=ncaashop&utm_medium=referral&utm_term=)
#   + [Jerseys](https://www.shopncaasports.com/d-8011?_s=bm_ncaashop_jerseys_dropdown&utm_source=ncaashop&utm_medium=referral&utm_term=ncaashop_)
#   + [Sideline Gear](https://www.shopncaasports.com/c-2406?_s=bm_ncaashop_sideline_gear_dropdown&utm_source=ncaashop&utm_medium=referral&utm_term=nca)
# * Tickets
#
#   ### Tickets
#
#   #### NCAATickets.com
#
#   + [NCAA Championship Tickets](https://www.ncaatickets.com/)
#   + [FCS](https://www.ncaatickets.com/championship/fcs-championship)
#   + [Women's Volleyball](https://www.ncaatickets.com/championship/womens-volleyball)
#   + [Men's Basketball](https://www.ncaatickets.com/championship/march-madness)
#   + [Women's Basketball](https://www.ncaatickets.com/championship/womens-final-four)
#
#   #### NCAA Hospitality Experiences
#
#   + [NCAA Tournament](http://bit.ly/NCAATMM)
#   + [Men's Final Four](http://bit.ly/NCAAFINAL4)
#   + [Women's Final Four](http://bit.ly/NCAAWF4)
#   + [Men’s College World Series](https://bit.ly/3mOYeCO)
#   + [Women’s College World Series](https://bit.ly/3vjNRee)
#
#   #### Marriott Bonvoy
#
#   + [Marriott Bonvoy Travel Hub](https://on.ncaa.com/marriott)
# * Settings
#
#   ### Settings
#
#   + [Feedback](/contact-us)
#
# Men's Basketball
# ----------------
#
# DI
# DII
# DIII
#
# [Home](/sports/basketball-men/d1)
#
# Scores
#
# [Bracket](/brackets/basketball-men/d1)
# [Rankings](/rankings/basketball-men/d1)
# [Standings](/standings/basketball-men/d1)
# [Stats](/stats/basketball-men/d1)
# [Men's Final Four](/mens-final-four)
# [Video](/video/basketball-men)
# [History](/history/basketball-men/d1)
# [NIT](/championships/basketball-men/nit)
#
#
#
#
# PRESENTED BY
#
# NCAA college basketball scores
# ==============================
#
# All ConferencesACCAmerica EastASUNAtlantic 10Big 12Big EastBig SkyBig SouthBig TenBig WestCAACUSAHorizonIvy LeagueMAACMACMEACMountain WestMVCNECOVCPatriotSECSoConSouthlandSummit LeagueSun BeltSWACThe AmericanWACWCC
#
# [Previous Month](/scoreboard/basketball-men/d1/2025/03/07)
# April 2025
# [Next Month](/scoreboard/basketball-men/d1/2025/05/07)
#
# [T
#
# 01](/scoreboard/basketball-men/d1/2025/04/01)
#
# [W
#
# 02](/scoreboard/basketball-men/d1/2025/04/02)
#
# [T
#
# 03](/scoreboard/basketball-men/d1/2025/04/03)
#
# [F
#
# 04](/scoreboard/basketball-men/d1/2025/04/04)
#
# [S
#
# 05](/scoreboard/basketball-men/d1/2025/04/05)
#
# [S
#
# 06](/scoreboard/basketball-men/d1/2025/04/06)
#
# [M
#
# 07](/scoreboard/basketball-men/d1/2025/04/07)
#
# [T
#
# 08](/scoreboard/basketball-men/d1/2025/04/08)
#
# [W
#
# 09](/scoreboard/basketball-men/d1/2025/04/09)
#
# [T
#
# 10](/scoreboard/basketball-men/d1/2025/04/10)
#
# [F
#
# 11](/scoreboard/basketball-men/d1/2025/04/11)
#
# [S
#
# 12](/scoreboard/basketball-men/d1/2025/04/12)
#
# [S
#
# 13](/scoreboard/basketball-men/d1/2025/04/13)
#
# [M
#
# 14](/scoreboard/basketball-men/d1/2025/04/14)
#
# [T
#
# 15](/scoreboard/basketball-men/d1/2025/04/15)
#
# [W
#
# 16](/scoreboard/basketball-men/d1/2025/04/16)
#
# [T
#
# 17](/scoreboard/basketball-men/d1/2025/04/17)
#
# [F
#
# 18](/scoreboard/basketball-men/d1/2025/04/18)
#
# [S
#
# 19](/scoreboard/basketball-men/d1/2025/04/19)
#
# [S
#
# 20](/scoreboard/basketball-men/d1/2025/04/20)
#
# [M
#
# 21](/scoreboard/basketball-men/d1/2025/04/21)
#
# [T
#
# 22](/scoreboard/basketball-men/d1/2025/04/22)
#
# [W
#
# 23](/scoreboard/basketball-men/d1/2025/04/23)
#
# [T
#
# 24](/scoreboard/basketball-men/d1/2025/04/24)
#
# [F
#
# 25](/scoreboard/basketball-men/d1/2025/04/25)
#
# [S
#
# 26](/scoreboard/basketball-men/d1/2025/04/26)
#
# [S
#
# 27](/scoreboard/basketball-men/d1/2025/04/27)
#
# [M
#
# 28](/scoreboard/basketball-men/d1/2025/04/28)
#
# [T
#
# 29](/scoreboard/basketball-men/d1/2025/04/29)
#
# [W
#
# 30](/scoreboard/basketball-men/d1/2025/04/30)
#
# [FINAL
#
# Championship
#
# * ![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/florida.svg)
#
#   1
#   Florida
#   65
# * ![](https://www.ncaa.com/sites/default/files/images/logos/schools/bgl/houston.svg)
#
#   1
#   Houston
#   63](/game/6384744)
#
# ##### Advertisement
#
# ![](https://www.ncaa.com/modules/custom/casablanca_core/img/sportbanners/basketball-men.svg)
#
# Division I
#
# Men's Basketball Championship
#
# April 5 & 7, 2025
#
# Alamodome | San Antonio, TX
#
# * [Tickets](https://www.ncaatickets.com/)
# * [Championship Info](https://www.ncaa.com/championships)
# * [Game Program](https://www.ncaa.com/gameprograms)
#
#
#
#
# NCAA Footer Navigation Menu
# ---------------------------
#
# * Featured Sections
#   + [March Madness](/march-madness)
#   + [Bracket Challenge Game](https://smart.link/48lfg29uw1j42?device_id=device_id&cid=bcg2021_editorial_editorial-tile&creative_id=&cp_1=&site_id=bcg2021_editorial_editorial-tile)
#   + [Video](/video)
#   + [TV Broadcast Schedule](https://web1.ncaa.org/NCAATV/exec/query)
#   + [Newsletters](/newsletter-signup)
# * Experience It Live
#   + [Championship Tickets](https://www.ncaatickets.com/)
#   + [NCAA Fan Experience](https://onlocationexp.com/ncaa?utm_source=ncaa.com&utm_medium=referral&utm_campaign=ncaa_experience-ncaa_web_bottom_navigation)
#   + [NCAA Travel](/travel)
#   + [DI Men's Basketball Tickets](https://www.ncaatickets.com/championship/march-madness)
#   + [DI Women's Basketball Tickets](https://www.ncaatickets.com/championship/womens-final-four)
#   + [Ticket Terms](https://www.ncaatickets.com/ncaa-ticketed-events-terms-conditions)
# * NCAA Championships
#   + [Championship Central](/championships)
#   + [Championship Store](/shop)
#   + [Men's Final Four](/mens-final-four)
#   + [Women's Final Four](/womensfinalfour)
#   + [Men's College World Series](/cws)
#   + [Women's College World Series](/championships/softball/d1)
# * About the NCAA
#   + [NCAA.org](http://www.ncaa.org/)
#   + [Hall of Champions](http://www.ncaahallofchampions.org/index.php)
#   + [Eligibility Center](http://www.ncaa.org/student-athletes/future)
#   + [Corporate Champions & Partners](/news/ncaa/article/2011-02-25/corporate-champions-and-partners)
#   + [Broadcast Media and Services](/media)
#   + [Careers in College Athletics](http://on.ncaa.com/2pAbX4M)
#   + [Elite 90](/elite-90)
#
# * [Feedback](/contact-us)
# * [Terms of Service](/tos)
# * [Accessibility and Closed Captioning](/closed-captioning)
# * [AdChoices
#   ![](https://i.cdn.turner.com/cnn/.e/img/3.0/global/misc/logo_ad_choices_footer.png)](https://www.wbdprivacy.com/policycenter/b2c/)
# * [Privacy Policy](/privacy)
# * [RSS](/rss)
# * Do Not Sell or Share My Personal Information
#
# © 2025 NCAA | © 2025 TNT Sports, a division of Warner Bros. Discovery | All Rights Reserved
# NCAA.com is a part of Bleacher Report - Turner Sports Network, part of the Turner Sports and Entertainment Network.

# %%
# basic tool parsing -- universal but less robust, use instructor/outlines/API-provider parsing for more anything production-grade
import re
import json

def parse_thinking_from_response(response: str) -> str | None:
    """Parse a thinking from a response."""
    thinking = re.search(r'<think>(.*?)</think>', response, re.DOTALL)
    if thinking:
        return thinking.group(1)
    return None

def parse_tool_from_response(response: str) -> dict | None:
    """Parse a tool from a response."""
    tool_call = re.search(r'<tool>(.*?)</tool>', response, re.DOTALL)
    if tool_call:
        return json.loads(tool_call.group(1))
    return None

def parse_answer_from_response(response: str) -> str | None:
    """Parse an answer from a response."""
    answer = re.search(r'<answer>(.*?)</answer>', response, re.DOTALL)
    if answer:
        return answer.group(1)
    return None

def call_tool(tool_call: dict) -> str:
    """Call a tool with the given tool call."""
    if tool_call['name'] == 'search':
        return search(tool_call['args']['query'])
    elif tool_call['name'] == 'fetch':
        return fetch(tool_call['args']['url'])
    else:
        return f"Error: Tool {tool_call['name']} not found"
    
# test
tool_call = {"name": "search", "args": {"query": "latest basketball scores"}}


example_response = """
<think>
I'll do a web search to retrieve the most recent news headlines and updates related to the NBA.
</think>
<tool>
{"name": "search", "args": {"query": "latest NBA news"}}
</tool>
"""

tool_call = parse_tool_from_response(example_response) # type: ignore
print(tool_call)
# Out:
# {'name': 'search', 'args': {'query': 'latest NBA news'}}

# %%
tool_result = call_tool(tool_call) # type: ignore
print(tool_result)
# Out:
# •  NBA (nba.com)
#    NBA News - Latest team, player and league news | NBA.com
#    <strong>NBA</strong> <strong>News</strong>: Your source of the most updated official <strong>NBA</strong> <strong>news</strong>. Stay current on the league, team and player <strong>news</strong>, scores, stats, standings from <strong>NBA</strong>.
#    https://www.nba.com/news
#
# •  ESPN (Entertainment and Sports Programming Network)
#    NBA on ESPN - Scores, Stats and Highlights
#    Visit ESPN for <strong>NBA</strong> live scores, video highlights and <strong>latest</strong> <strong>news</strong>. Stream games on ESPN and play Fantasy Basketball.
#    https://www.espn.com/nba/
#
# •  NBA (nba.com)
#    The official site of the NBA for the latest NBA Scores, Stats & News. | NBA.com
#    Follow the action on <strong>NBA</strong> scores, schedules, stats, <strong>news</strong>, teams, and players. Buy tickets or watch the games anywhere with <strong>NBA</strong> League Pass.
#    https://www.nba.com/
#
# •  Cbssports (cbssports.com)
#    NBA Basketball - News, Scores, Stats, Standings, and Rumors - National Basketball Association - CBSSports.com
#    CBS Sports has the <strong>latest</strong> <strong>NBA</strong> Basketball <strong>news</strong>, live scores, player stats, standings, fantasy games, and projections.
#    https://www.cbssports.com/nba/
#
# •  NBA (nba.com)
#    Top Stories | NBA.com
#    Does your local basketball court deserve an upgrade? Submit your story for the chance to win a full-court renovation · Tyrese Haliburton powers the Pacers past the Knicks with an unprecedented performance. Plus, an elimination Game 5 tonight in OKC
#    https://www.nba.com/news/category/top-stories
#
# •  RealGM (basketball.realgm.com)
#    NBA News, NBA Rumors, Trades, Free Agency - RealGM
#    With a dearth of available cap space in the <strong>NBA</strong> just as the league&#x27;s new media rights deals will increase the salary cap in the coming years, there are a number of teams with title ambitions who must enter the trade market to make meaningful changes.
#    https://basketball.realgm.com/nba/news
#
# •  Yahoo! (sports.yahoo.com)
#    NBA News, Video, Rumors, Scores, Stats, Standings - Yahoo Sports
#    The Thunder were in a different weight class that the Timberwolves and are now <strong>NBA</strong> Finals-bound.
#    https://sports.yahoo.com/nba/
#
# •  Bleacherreport (bleacherreport.com)
#    NBA | NBA News, Scores, Highlights, Stats, Standings, and Rumors | Bleacher Report
#    Be the best <strong>NBA</strong> fan you can be with Bleacher Report. Keep up with the <strong>latest</strong> storylines, expert analysis, highlights, scores and more.
#    https://bleacherreport.com/nba
#
# •  HoopsHype (hoopshype.com)
#    NBA Rumors and News | HoopsHype
#    Get the <strong>latest</strong> <strong>news</strong> on free agency, trades, salaries and more on HoopsHype Rumors.
#    https://hoopshype.com/rumors/
#
# •  Sportspyder (sportspyder.com)
#    The Latest NBA News
#    We cannot provide a description for this page right now
#    https://sportspyder.com/sports/nba/news

# %%
# agent loop
final_answer = ""

question = "What is the latest news in the NBA? Give me a 3 paragraph report."
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question},
]

turns = 0
while True:
    turns += 1
    retries = 0 
    while retries < 5:
        try:
            response = client.chat.completions.create(
                model=model_name,
                messages=messages, # type: ignore
            )
            response = response.choices[0].message.content # type: ignore
            # parse for thinking, tool call, and/or answer 
            maybe_thinking = parse_thinking_from_response(response) # type: ignore
            maybe_tool_call = parse_tool_from_response(response) # type: ignore
            maybe_answer = parse_answer_from_response(response) # type: ignore
            if maybe_thinking or maybe_tool_call or maybe_answer:
                break
        except Exception as e:
            print(f"Error: {e}")
            retries += 1
    print("=== Turn", turns, "===")
    if maybe_thinking: # type: ignore
        thinking = maybe_thinking.strip()
        print(f"Thinking: {thinking}")
    if maybe_tool_call: # type: ignore
        tool_call = maybe_tool_call
        tool_result = call_tool(tool_call)
        print(f"Tool call: {tool_call}")
        print(f"Tool result: {tool_result[:100]}")
        messages.append({"role": "user", "content": tool_result})
    elif maybe_answer: # type: ignore
        final_answer = maybe_answer
        break
    else:
        print("Error: No tool call or answer found")
        break
# Out:
# === Turn 1 ===
# Thinking: I will search for the latest NBA news to provide a 3-paragraph summary that covers top stories, player updates, and league developments.
# Tool call: {'name': 'search', 'args': {'query': 'latest NBA news'}}
# Tool result: •  NBA (nba.com)
#    NBA News - Latest team, player and league news | NBA.com
#    <strong>NBA</strong>
# === Turn 2 ===
# Thinking: To provide the latest NBA news, I will check the official NBA.com news page for the most updated and reliable information on games, player performances, and league events.
# Tool call: {'name': 'fetch', 'args': {'url': 'https://www.nba.com/news'}}
# Tool result: NBA News - Latest team, player and league news | NBA.com
#
# Navigation Toggle[![NBA Logo](https://cdn.
# === Turn 3 ===
# Thinking: I now have the latest top headlines and news from NBA.com, including playoff results, standout player performances, and major league updates. I can now synthesize this information into a concise three-paragraph report.

# %%
print(f"Final answer: {final_answer}")
# Out:
# Final answer:
# The Oklahoma City Thunder have clinched a spot in the NBA Finals for the first time in 13 years, eliminating the Minnesota Timberwolves with an impressive performance characterized by star power, depth, and defense. Shai Gilgeous-Alexander, recently named the 2024-25 Kia NBA MVP, and his young supporting cast, including Jalen Williams and Chet Holmgren, have proven pivotal throughout the playoffs, propelling OKC back to the league’s biggest stage. Their balanced team effort and defensive prowess set a blueprint for postseason success that young teams around the league will look to emulate.
#
# Meanwhile, the Eastern Conference Finals are heating up with the Indiana Pacers taking a commanding 3-1 lead over the New York Knicks. Tyrese Haliburton made history in Game 4, posting a remarkable triple-double with at least 30 points, 15 assists, and 10 rebounds—without a single turnover—a feat never before achieved in NBA playoff history. As Indiana’s offense continues to surge, the Knicks face elimination and hope to rally at home to extend the series.
#
# Off the court, Denver Nuggets guard Russell Westbrook has undergone surgery to repair two breaks in his right hand, capping a season marked by both tough play and unfortunate injury. The coaching carousel continues as David Adelman was introduced as the Nuggets’ new head coach, promising a focus on team conditioning and fresh strategies. As the playoffs near their climax and the NBA Finals approach, fans can expect even more excitement and dramatic performances in the days ahead.
#
# Sources: [NBA.com Latest News](https://www.nba.com/news)

# %%
### Models as tools

def ask_model(question: str, url: str) -> str:
    """Ask a model a question about a URL and return the answer."""

    fetch_result = fetch(url)
    system_prompt = "You are a helpful assistant that can answer questions about a given URL."
    prompt = f"""
    Here is the content of the URL {url}:
    {fetch_result}

    Here is the question:
    {question}
    """
    messages = [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": prompt},
    ]
    # ask model to answer question about url
    answer = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=messages, # type: ignore
    )
    return answer.choices[0].message.content # type: ignore

# test
question = "What is the latest news in the NBA?."
url = "https://www.nba.com/news"
answer = ask_model(question, url)
print(answer)
# Out:
# The latest NBA news includes the following headlines:
#
# 1. "5 takeaways: Thunder finish Wolves in 5" - Oklahoma City Thunder advance to the NBA Finals with a strong close-out win over the Minnesota Timberwolves. (5 hours ago)
#
# 2. "4 stats to know for Knicks-Pacers Game 5" - Indiana Pacers hold a 3-1 series lead over the New York Knicks, with their offense being a key factor. (Recent)
#
# 3. "5 key stats from OKC's run to NBA Finals" - Oklahoma City Thunder have impressive stats as they return to the NBA Finals. (Recent)
#
# 4. "Thunder showing blueprint for success" - Isiah Thomas praises the Thunder's organization and suggests Minnesota Timberwolves could learn from them. (Video, 6 minutes duration)
#
# 5. "Adelman reveals Nuggets' offseason plans" - New Denver Nuggets coach discusses team conditioning and strategies. (19 hours ago)
#
# 6. "5 takeaways: Haliburton dazzles in Game 4" - Tyrese Haliburton posts a triple-double, helping the Indiana Pacers in Game 4 against the Knicks. (15 hours ago)
#
# 7. "Shaqtin’ A Fool: Best of 2024-25 season" - Highlight reel with humorous NBA moments from the season. (May 28, 2025)
#
# 8. "All-Access: Flagg at NBA Draft Combine" - Prospect Cooper Flagg showcases his skills at the Combine. (May 22, 2025)
#
# 9. "Gilgeous-Alexander named '24-25 Kia MVP" - Shai Gilgeous-Alexander wins the MVP award for the 2024-25 NBA season. (May 21, 2025)
#
# There are also ongoing updates from the current playoff games, including Eastern and Western conference finals games, player performances, injury news such as Russell Westbrook's hand surgery, and fantasy basketball insights.

# %%
# 

import os
from openai import OpenAI

model_name = "gpt-4.1"
base_url = "https://api.openai.com/v1"
client = OpenAI(base_url=base_url, api_key=os.getenv("OPENAI_API_KEY"))

system_prompt = """
You are a helpful assistant that can answer questions and help with tasks, such as drafting short research reports. Cite your sources when relevant. 

You have access to the following tools:

- search(query: str) -> str: Searches the web and returns summaries of top results.
- fetch(url: str) -> str: Fetches the content of a given URL and returns it as a markdown page.
- ask_model(question: str, url: str) -> str: Ask an AI helper model a question about a given URL and return the answer.

You may call one tool per turn, for up to 10 turns, before giving your final answer.

If you expect that a web page's content may be fairly long, you should opt to use the `ask_model` tool instead of `fetch`.

In each turn, you should respond in the following format:

<think>
[your thoughts here]
</think>
<tool>
JSON with the following fields:
- name: The name of the tool to call
- args: A dictionary of arguments to pass to the tool (must be valid JSON)
</tool>

When you are done, give your final answer in the following format:

<answer>
[your final answer here]
</answer>
"""

messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": "What is the latest news in the NBA?"},
]

response = client.chat.completions.create(
    model=model_name,
    messages=messages, # type: ignore
)

response = response.choices[0].message.content # type: ignore
print(response)
# Out:
# <think>
# I'll search for the latest news in the NBA to provide the most recent updates, including trades, injuries, game results, or other major headlines.
# </think>
# <tool>
# {
#   "name": "search",
#   "args": {
#     "query": "latest NBA news"
#   }
# }
# </tool>

# %%
# updated call_tool
def call_tool(tool_call: dict) -> str:
    """Call a tool with the given tool call."""
    if tool_call['name'] == 'search':
        return search(tool_call['args']['query'])
    elif tool_call['name'] == 'fetch':
        return fetch(tool_call['args']['url'])
    elif tool_call['name'] == 'ask_model':
        return ask_model(tool_call['args']['question'], tool_call['args']['url'])
    else:
        return f"Error: Tool {tool_call['name']} not found"
    
# agent loop
final_answer = ""

question = "What is the latest news in the NBA? Give me a 3 paragraph report."
messages = [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": question},
]

turns = 0
while True:
    turns += 1
    retries = 0 
    while retries < 5:
        try:
            response = client.chat.completions.create(
                model=model_name,
                messages=messages, # type: ignore
            )
            response = response.choices[0].message.content # type: ignore
            # parse for thinking, tool call, and/or answer 
            maybe_thinking = parse_thinking_from_response(response) # type: ignore
            maybe_tool_call = parse_tool_from_response(response) # type: ignore
            maybe_answer = parse_answer_from_response(response) # type: ignore
            if maybe_thinking or maybe_tool_call or maybe_answer:
                break
        except Exception as e:
            print(f"Error: {e}")
            retries += 1
    print("=== Turn", turns, "===")
    if maybe_thinking: # type: ignore
        thinking = maybe_thinking.strip()
        print(f"Thinking: {thinking}")
    if maybe_tool_call: # type: ignore
        tool_call = maybe_tool_call
        tool_result = call_tool(tool_call)
        print(f"Tool call: {tool_call}")
        print(f"Tool result: {tool_result[:100]}")
        messages.append({"role": "user", "content": tool_result})
    elif maybe_answer: # type: ignore
        final_answer = maybe_answer
        break
    else:
        print("Error: No tool call or answer found")
        break
# Out:
# === Turn 1 ===
# Thinking: I'll search for the latest NBA news to gather current updates and trends. Then, I'll summarize the findings into a concise three-paragraph report.
# Tool call: {'name': 'search', 'args': {'query': 'latest NBA news'}}
# Tool result: •  NBA (nba.com)
#    NBA News - Latest team, player and league news | NBA.com
#    <strong>NBA</strong>
# === Turn 2 ===
# Thinking: The best way to get the latest, up-to-date NBA news in detail is to check the "Top Stories" or main news page on NBA.com. I will use the "Top Stories" page from NBA.com to ensure official and current news for my report.
# Tool call: {'name': 'ask_model', 'args': {'question': 'What are the most important and latest NBA news stories or developments today?', 'url': 'https://www.nba.com/news/category/top-stories'}}
# Tool result: The most important and latest NBA news stories and developments today from the NBA.com Top Stories s
# === Turn 3 ===

# %%
print(f"Final answer: {final_answer}")
# Out:
# Final answer:
# The latest NBA news centers around the Oklahoma City Thunder's remarkable return to the NBA Finals for the first time in 13 years. Key stats from their playoff run have underscored their defensive tenacity, the emergence of their young stars, and the remarkable versatility of Jalen Williams, who is averaging 20.5 points, 5.6 rebounds, 5.3 assists, and 1.7 steals over 15 postseason games. The Thunder clinched their Finals berth by defeating the Minnesota Timberwolves in five games, leveraging their depth and ability to perform in crucial moments.
#
# As the Western Conference Finals conclude, the focus in the Eastern Conference Finals shifts to the series between the Indiana Pacers and New York Knicks, with the Pacers leading 3-1. Tyrese Haliburton has delivered historic performances, including a triple-double with at least 30 points, 15 assists, 10 rebounds, and zero turnovers—a feat never before accomplished in NBA playoff history. The Knicks face elimination in a pivotal Game 5 hosted at Madison Square Garden, as they attempt to rally against the Pacers’ offensive firepower and resilient defense.
#
# Off the court, the Denver Nuggets have introduced new coach David Adelman, who has discussed plans for team conditioning and fresh strategies aimed at building on recent successes. Additionally, community engagement is highlighted by the NBA’s 'Every Court Has A Story' contest, offering local basketball courts a chance for renovation. As the playoffs intensify, standout individual performances and evolving team strategies remain at the forefront of NBA news, with the Finals rapidly approaching.

# %% [markdown]
# ### MCP Crash Course
#
# TLDR: MCP is basically just function calling
#
# Why:
# - multiple function methods
# - client/server architecture, clients + servers can manage their own state
# - standardized interface, portability
# - both Python + Typescript servers supported (uvx, npx)
#     - also Java/Kotlin/C#/Swift SDKs, but less popular
#
# Getting Started:
# - MCP Server [docs](https://modelcontextprotocol.io/quickstart/server)
# - MCP Client [docs](https://modelcontextprotocol.io/quickstart/client)
# - example servers: [modelcontextprotocol/servers](https://github.com/modelcontextprotocol/servers)
# - Other repositories:
#     - [Smithery](https://smithery.ai/)
#     - [mcp.so](https://mcp.so/)
#     - [awesome-mcp-servers](https://github.com/punkpeye/awesome-mcp-servers)
#
#
# MCP Clients:
# - Claude Desktop
# - Claude Code
# - Cursor, Windsurf, other IDEs

# %% [markdown]
# ### Deep Research via Claude Code
#
# Claude Code is set up to be a code agent by default, but can also be used as a sandbox for other agentic workflows
#
# We just need:
# - tools
# - instructions
# - examples?
# - ability to refine via feedback

# %%
basic_prompt = """
Write a report about upcoming tech events in NYC. Save the report as a markdown file in the reports folder.
"""

# %% [markdown]
# ##
